# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("aqi.csv")

# %%
data.head()
# Out:
#          date           state      area  number_of_monitoring_stations  \
# 0  30-04-2025     Maharashtra  Amravati                              2
# 1  30-04-2025           Bihar    Purnia                              1
# 2  30-04-2025  Madhya Pradesh     Katni                              1
# 3  30-04-2025    Chhattisgarh   Tumidih                              1
# 4  30-04-2025           Assam  Byrnihat                              1
#
#   prominent_pollutants  aqi_value air_quality_status  \
# 0                 PM10         78       Satisfactory
# 1                   CO         56       Satisfactory
# 2                   O3         98       Satisfactory
# 3                 PM10        103           Moderate
# 4                PM2.5         61       Satisfactory
#
#                                                 unit  note
# 0  number_of_monitoring_stations in Absolute Numb...   NaN
# 1  number_of_monitoring_stations in Absolute Numb...   NaN
# ...

# %%
data.describe()
# Out:
#        number_of_monitoring_stations      aqi_value  note
# count                  235785.000000  235785.000000   0.0
# mean                        1.870653     111.127294   NaN
# std                         3.071575      71.447353   NaN
# min                         1.000000       3.000000   NaN
# 25%                         1.000000      59.000000   NaN
# 50%                         1.000000      92.000000   NaN
# 75%                         1.000000     142.000000   NaN
# max                        40.000000     500.000000   NaN

# %%
data["state"],data["aqi_value"]
# Out:
# (0            Maharashtra
#  1                  Bihar
#  2         Madhya Pradesh
#  3           Chhattisgarh
#  4                  Assam
#                 ...
#  235780             Bihar
#  235781         Rajasthan
#  235782       Maharashtra
#  235783     Uttar Pradesh
#  235784            Odisha
#  Name: state, Length: 235785, dtype: object,
#  0          78
#  1          56
#  2          98
#  3         103
#  4          61
#           ...
#  235780    210
#  235781    158
#  235782    201
#  235783    128
#  235784    270
#  Name: aqi_value, Length: 235785, dtype: int64)

# %%
data = pd.DataFrame(data)

# %%
data.head()
# Out:
#          date           state      area  number_of_monitoring_stations  \
# 0  30-04-2025     Maharashtra  Amravati                              2
# 1  30-04-2025           Bihar    Purnia                              1
# 2  30-04-2025  Madhya Pradesh     Katni                              1
# 3  30-04-2025    Chhattisgarh   Tumidih                              1
# 4  30-04-2025           Assam  Byrnihat                              1
#
#   prominent_pollutants  aqi_value air_quality_status  \
# 0                 PM10         78       Satisfactory
# 1                   CO         56       Satisfactory
# 2                   O3         98       Satisfactory
# 3                 PM10        103           Moderate
# 4                PM2.5         61       Satisfactory
#
#                                                 unit  note
# 0  number_of_monitoring_stations in Absolute Numb...   NaN
# 1  number_of_monitoring_stations in Absolute Numb...   NaN
# ...

# %%
two_columns = data[['state','aqi_value']]

# %%
data.sort_values(by = 'aqi_value',ascending = False)
# Out:
#               date              state        area  \
# 196221  10-12-2022          Karnataka       Gadag
# 179558  10-03-2023     Madhya Pradesh      Ujjain
# 174386  04-04-2023     Andhra Pradesh  Vijayawada
# 48822   07-10-2024            Manipur      Imphal
# 179706  09-03-2023     Madhya Pradesh      Ujjain
# ...            ...                ...         ...
# 221599  05-07-2022          Karnataka  Davanagere
# 66819   22-07-2024  Arunachal Pradesh  Naharlagun
# 148844  06-08-2023            Mizoram      Aizawl
# 157784  24-06-2023              Assam     Silchar
# 160535  11-06-2023              Assam     Silchar
#
#         number_of_monitoring_stations prominent_pollutants  aqi_value  \
# 196221                              1                 PM10        500
# 179558                              1                PM2.5        500
# 174386                              1                PM2.5        500
# 48822                               1                PM2.5        500
# ...

# %%
pollutant_count = data.groupby(['prominent_pollutants']).size().reset_index(name = "count")

# %%
prominent_pollutants = pollutant_count.sort_values(by = "count",ascending = False)

# %%
prominent_pollutants.to_csv("prominent_pollutants.csv",index = False)

# %%
# List the top 5 and bottom 5 areas with highest average AQI. (Consider areas 
# which contains data from last 6 months: December 2024 to May 2025)

# %%
import pandas as pd

# %%
vahan = pd.read_csv("vahan.csv")

# %%
vahan
# Out:
#        year  month                        state                       rto  \
# 0      2025  April  Andaman and Nicobar Islands  All Vahan Running Office
# 1      2025  April  Andaman and Nicobar Islands  All Vahan Running Office
# 2      2025  April  Andaman and Nicobar Islands  All Vahan Running Office
# 3      2025  April  Andaman and Nicobar Islands  All Vahan Running Office
# 4      2025  April  Andaman and Nicobar Islands  All Vahan Running Office
# ...     ...    ...                          ...                       ...
# 64836  2022  April                  West Bengal  All Vahan Running Office
# 64837  2022  April                  West Bengal  All Vahan Running Office
# 64838  2022  April                  West Bengal  All Vahan Running Office
# 64839  2022  April                  West Bengal  All Vahan Running Office
# 64840  2022  April                  West Bengal  All Vahan Running Office
#
#                        vehicle_class            fuel  value  \
# ...

# %%
ev1 = vahan["vehicle_class"].isin(["E-RIKSHAW(P)","E-RICKSHAW WITH CART (G)"])

# %%
import numpy as np

# %%
vahan['vehicle_class'] = vahan['vehicle_class'].astype('category')

# %%
ev = vahan['vehicle_class'].value_counts()

# %%
ev.head(40)
# Out:
# vehicle_class
# MOTOR CAR                                   7885
# MOTOR CAB                                   5233
# GOODS CARRIER                               4836
# THREE WHEELER (PASSENGER)                   4640
# M-CYCLE/SCOOTER                             3957
# THREE WHEELER (GOODS)                       3274
# MAXI CAB                                    2427
# AMBULANCE                                   2140
# BUS                                         2138
# MOPED                                       1874
# ADAPTED VEHICLE                             1719
# MOTORISED CYCLE (CC > 25CC)                 1448
# OMNI BUS (PRIVATE USE)                      1225
# EDUCATIONAL INSTITUTION BUS                 1194
# E-RICKSHAW(P)                               1183
# M-CYCLE/SCOOTER-WITH SIDE CAR               1171
# AGRICULTURAL TRACTOR                        1153
# CONSTRUCTION EQUIPMENT VEHICLE              1106
# E-RICKSHAW WITH CART (G)                    1046
# ...

# %%
ev = ev.isin(["E-RIKSHAW(P)","E-RIKSHAW WITH CART(G)"])

# %%
vahan.columns = vahan.columns.str.strip()  # remove any spaces

# %%
vahan[vahan["vehicle_class"] ==  "E-RICKSHAW WITH CART (G)"]["vehicle_class"].value_counts()
# Out:
# vehicle_class
# E-RICKSHAW WITH CART (G)          1046
# ADAPTED VEHICLE                      0
# AMBULANCE                            0
# AGRICULTURAL TRACTOR                 0
# ARMOURED/SPECIALISED VEHICLE         0
#                                   ...
# TRAILER FOR PERSONAL USE             0
# TREE TRIMMING VEHICLE                0
# VEHICLE FITTED WITH COMPRESSOR       0
# VEHICLE FITTED WITH GENERATOR        0
# VEHICLE FITTED WITH RIG              0
# Name: count, Length: 72, dtype: int64

# %%
data
# Out:
#               date           state          area  \
# 0       30-04-2025     Maharashtra      Amravati
# 1       30-04-2025           Bihar        Purnia
# 2       30-04-2025  Madhya Pradesh         Katni
# 3       30-04-2025    Chhattisgarh       Tumidih
# 4       30-04-2025           Assam      Byrnihat
# ...            ...             ...           ...
# 235780  01-04-2022           Bihar         Arrah
# 235781  01-04-2022       Rajasthan        Jaipur
# 235782  01-04-2022     Maharashtra    Chandrapur
# 235783  01-04-2022   Uttar Pradesh      Varanasi
# 235784  01-04-2022          Odisha  Brajrajnagar
#
#         number_of_monitoring_stations prominent_pollutants  aqi_value  \
# 0                                   2                 PM10         78
# 1                                   1                   CO         56
# 2                                   1                   O3         98
# 3                                   1                 PM10        103
# ...
